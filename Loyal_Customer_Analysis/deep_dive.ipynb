# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 한글 폰트(윈도우 기준)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_csv("../data/train_raw.csv")

# satisfaction → 이진 label로 변경
df['label'] = df['satisfaction'].map({
    'neutral or dissatisfied': 0,
    'satisfied': 1
})

# %%
service_columns = [
    'Online boarding', 'Inflight entertainment', 'Inflight wifi service',
    'Seat comfort', 'On-board service', 'Cleanliness', 'Leg room service',
    'Inflight service', 'Ease of Online booking', 'Baggage handling',
    'Checkin service', 'Food and drink', 'Gate location',
    'Departure/Arrival time convenient'
]

# 0은 '이용하지 않음' → NaN으로 처리
df[service_columns] = df[service_columns].replace(0, np.nan)

# %%
# 결측치 처리 (단순히 평균 대치)
df[service_columns] = df[service_columns].fillna(df[service_columns].mean())

# %%
# 충성/비충성 고객 분리
loyal = df[df['Customer Type'] == 'Loyal Customer'].copy()
disloyal = df[df['Customer Type'] == 'disloyal Customer'].copy()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# 충성 고객 서비스 상관계수
loyal_corr = (
    loyal[service_columns + ['label']]
    .corr()['label']
    .drop('label')
    .sort_values(ascending=False)
)

# 비충성 고객 서비스 상관계수
disloyal_corr = (
    disloyal[service_columns + ['label']]
    .corr()['label']
    .drop('label')
    .sort_values(ascending=False)
)

# 두 상관계수를 하나의 DataFrame으로 합치기
corr_compare = pd.DataFrame({
    'Loyal_corr': loyal_corr,
    'Disloyal_corr': disloyal_corr
})

# 보기 좋게 정렬 (예: 충성 고객 기준으로 정렬)
corr_compare = corr_compare.sort_values('Loyal_corr', ascending=False)

# 보기 좋게 반올림
corr_compare = corr_compare.round(4)

corr_compare
# Out:
#                                    Loyal_corr  Disloyal_corr
# Online boarding                        0.5368         0.5790
# Inflight entertainment                 0.4611         0.0229
# Seat comfort                           0.3980         0.0114
# Leg room service                       0.3598         0.0702
# Cleanliness                            0.3550         0.0126
# Inflight wifi service                  0.3457         0.6275
# On-board service                       0.3387         0.2109
# Baggage handling                       0.2648         0.2124
# Inflight service                       0.2619         0.2068
# Food and drink                         0.2382         0.0351
# Checkin service                        0.2374         0.2223
# Ease of Online booking                 0.1719         0.5940
# Gate location                          0.0159        -0.0837
# Departure/Arrival time convenient     -0.1426         0.4062

# %%
# 충성 고객
X_loyal = loyal[service_columns]
y_loyal = loyal['label']

loyal_model = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(max_iter=1000))
])
loyal_model.fit(X_loyal, y_loyal)

loyal_coefs = pd.Series(
    loyal_model.named_steps['logreg'].coef_[0],
    index=service_columns
)

# 비충성 고객
X_dis = disloyal[service_columns]
y_dis = disloyal['label']

disloyal_model = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(max_iter=1000))
])
disloyal_model.fit(X_dis, y_dis)

disloyal_coefs = pd.Series(
    disloyal_model.named_steps['logreg'].coef_[0],
    index=service_columns
)

# %%
from scipy.stats import ttest_ind
import pandas as pd

# 결과 저장 리스트
rows = []

for col in service_columns:
    loyal_scores = loyal[col]
    disloyal_scores = disloyal[col]

    # Welch’s t-test (equal_var=False)
    stat, p = ttest_ind(loyal_scores, disloyal_scores, equal_var=False)

    # 평균 계산
    loyal_mean = loyal_scores.mean()
    disloyal_mean = disloyal_scores.mean()

    # 해석
    significance = "차이 있음" if p < 0.05 else "차이 없음"

    rows.append({
        "Service": col,
        "Loyal Mean": round(loyal_mean, 3),
        "Disloyal Mean": round(disloyal_mean, 3),
        "Mean Diff (L - D)": round(loyal_mean - disloyal_mean, 3),
        "p-value": p,
        "Interpretation": significance
    })

# DataFrame 생성
ttest_summary = pd.DataFrame(rows)

# p-value 정렬
ttest_summary = ttest_summary.sort_values("p-value")

# 출력
ttest_summary
# Out:
#                               Service  Loyal Mean  Disloyal Mean  \
# 0                     Online boarding       3.434          2.854
# 3                        Seat comfort       3.539          2.994
# 13  Departure/Arrival time convenient       3.287          2.948
# 1              Inflight entertainment       3.428          3.048
# 5                         Cleanliness       3.339          3.054
# 11                     Food and drink       3.243          3.039
# 4                    On-board service       3.417          3.228
# 6                    Leg room service       3.400          3.218
# 10                    Checkin service       3.324          3.218
# 9                    Baggage handling       3.618          3.694
# 7                    Inflight service       3.628          3.697
# 8              Ease of Online booking       2.893          2.829
# 12                      Gate location       2.973          2.993
# 2               Inflight wifi service       2.814          2.811
#
#     Mean Diff (L - D)        p-value Interpretation
# 0               0.580   0.000000e+00          차이 있음
# 3               0.544   0.000000e+00          차이 있음
# 13              0.338  6.799436e-267          차이 있음
# 1               0.380  4.698190e-255          차이 있음
# 5               0.284  1.310465e-145          차이 있음
# 11              0.204   3.774928e-76          차이 있음
# 4               0.189   7.775089e-75          차이 있음
# 6               0.182   5.564623e-66          차이 있음
# 10              0.105   1.368180e-24          차이 있음
# 9              -0.076   2.514450e-17          차이 있음
# 7              -0.069   1.926662e-14          차이 있음
# 8               0.064   6.441800e-11          차이 있음
# 12             -0.020   3.165672e-02          차이 있음
# 2               0.003   7.530639e-01          차이 없음

# %%
# 기본 틀
summary = pd.DataFrame(index=service_columns)

# 평균 점수
summary['Loyal_mean'] = loyal[service_columns].mean()
summary['Disloyal_mean'] = disloyal[service_columns].mean()
summary['Mean_diff (L - D)'] = summary['Loyal_mean'] - summary['Disloyal_mean']

# 상관계수
summary['Loyal_corr'] = loyal_corr
summary['Disloyal_corr'] = disloyal_corr

# 회귀 계수
summary['Loyal_coef'] = loyal_coefs
summary['Disloyal_coef'] = disloyal_coefs

# t-test
summary['ttest_p'] = ttest_summary.set_index('Service')['p-value']

# 정렬
summary = summary.sort_values('Loyal_coef', ascending=False)

summary
# Out:
#                                    Loyal_mean  Disloyal_mean  \
# Online boarding                      3.434181       2.853735
# Inflight wifi service                2.814268       2.811227
# Leg room service                     3.399537       3.217849
# On-board service                     3.416932       3.228228
# Checkin service                      3.323579       3.218166
# Inflight entertainment               3.427988       3.048206
# Seat comfort                         3.538893       2.994415
# Cleanliness                          3.338688       3.054265
# Gate location                        2.973246       2.993309
# Ease of Online booking               2.892964       2.829266
# Baggage handling                     3.618030       3.693588
# Inflight service                     3.627956       3.696802
# Food and drink                       3.242632       3.038983
# Departure/Arrival time convenient    3.286610       2.948191
#
#                                    Mean_diff (L - D)  Loyal_corr  \
# Online boarding                             0.580446    0.536769
# Inflight wifi service                       0.003040    0.345710
# Leg room service                            0.181688    0.359785
# On-board service                            0.188704    0.338667
# Checkin service                             0.105414    0.237380
# Inflight entertainment                      0.379782    0.461060
# Seat comfort                                0.544478    0.398032
# Cleanliness                                 0.284424    0.354974
# Gate location                              -0.020063    0.015914
# Ease of Online booking                      0.063698    0.171897
# Baggage handling                           -0.075558    0.264824
# Inflight service                           -0.068846    0.261880
# Food and drink                              0.203649    0.238172
# Departure/Arrival time convenient           0.338419   -0.142588
#
#                                    Disloyal_corr  Loyal_coef  Disloyal_coef  \
# Online boarding                         0.579002    1.010960       1.820403
# Inflight wifi service                   0.627491    0.718620       2.730082
# Leg room service                        0.070200    0.525226       0.056619
# On-board service                        0.210937    0.432133       0.287324
# Checkin service                         0.222327    0.339569       0.399031
# Inflight entertainment                  0.022861    0.330048       0.150077
# Seat comfort                            0.011375    0.256900       0.018195
# Cleanliness                             0.012616    0.199100      -2.240128
# Gate location                          -0.083748    0.190334      -0.135840
# Ease of Online booking                  0.594026    0.187180      -1.998020
# Baggage handling                        0.212385    0.062606       0.245727
# Inflight service                        0.206775   -0.017881       0.221257
# Food and drink                          0.035085   -0.087942       2.132918
# Departure/Arrival time convenient       0.406247   -0.947346       0.244191
#
#                                          ttest_p
# Online boarding                     0.000000e+00
# Inflight wifi service               7.530639e-01
# Leg room service                    5.564623e-66
# On-board service                    7.775089e-75
# Checkin service                     1.368180e-24
# Inflight entertainment             4.698190e-255
# Seat comfort                        0.000000e+00
# Cleanliness                        1.310465e-145
# Gate location                       3.165672e-02
# Ease of Online booking              6.441800e-11
# Baggage handling                    2.514450e-17
# Inflight service                    1.926662e-14
# Food and drink                      3.774928e-76
# Departure/Arrival time convenient  6.799436e-267

# %%
# 상관계수 기반 투자 우선순위 Top3 추출
# 충성 고객 Top 3 서비스
top3_loyal = loyal_corr.sort_values(ascending=False).head(3)

# 비충성 고객 Top 3 서비스
top3_disloyal = disloyal_corr.sort_values(ascending=False).head(3)

print("[상관 기반]Loyal Customer 투자 우선순위 Top 3")
print(top3_loyal.to_string())

print("\n[상관 기반]Disloyal Customer 투자 우선순위 Top 3")
print(top3_disloyal.to_string())
# Out:
# [상관 기반]Loyal Customer 투자 우선순위 Top 3
# Online boarding           0.536769
# Inflight entertainment    0.461060
# Seat comfort              0.398032
#
# [상관 기반]Disloyal Customer 투자 우선순위 Top 3
# Inflight wifi service     0.627491
# Ease of Online booking    0.594026
# Online boarding           0.579002

# %%
# 회귀계수 기반 투자 우선순위 Top3 추출
# 회귀 계수 기반 Top 3
top3_loyal_reg = loyal_coefs.sort_values(ascending=False).head(3)
top3_disloyal_reg = disloyal_coefs.sort_values(ascending=False).head(3)

print("[회귀 기반] Loyal Customer 우선 투자 Top 3")
print(top3_loyal_reg.to_string())

print("\n[회귀 기반] Disloyal Customer 우선 투자 Top 3")
print(top3_disloyal_reg.to_string())
# Out:
# [회귀 기반] Loyal Customer 우선 투자 Top 3
# Online boarding          1.010960
# Inflight wifi service    0.718620
# Leg room service         0.525226
#
# [회귀 기반] Disloyal Customer 우선 투자 Top 3
# Inflight wifi service    2.730082
# Food and drink           2.132918
# Online boarding          1.820403

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# -----------------------------
# 1. 추가 파생 변수 생성 (AgeGroup, DistanceGroup)
# -----------------------------
df['AgeGroup'] = pd.cut(df['Age'], bins=[0,19,29,39,49,59,69,150],
                        labels=['10대','20대','30대','40대','50대','60대','70대+'])

df['DistanceGroup'] = pd.cut(df['Flight Distance'], 
                             bins=[0, 1500, 3500, 10000],
                             labels=['Short','Medium','Long'])

# -----------------------------
# 2. Customer Type 분리
# -----------------------------
groups = {
    'Loyal': df[df['Customer Type'] == 'Loyal Customer'],
    'Disloyal': df[df['Customer Type'] == 'disloyal Customer']
}

# -----------------------------
# 3. 세부 subgroup 정의
# Type of Travel 추가됨
# -----------------------------
sub_conditions = {
    'Gender': df['Gender'].unique(),
    'AgeGroup': df['AgeGroup'].unique(),
    'Class': df['Class'].unique(),
    'DistanceGroup': df['DistanceGroup'].unique(),
    'Type of Travel': df['Type of Travel'].unique()   # ← 추가됨!!!
}

# -----------------------------
# 4. 회귀 자동 실행 함수
# -----------------------------
def run_regression(data, service_columns):
    X = data[service_columns]
    y = data['label']

    if len(data) < 80:      # 데이터 너무 적으면 skip
        return None

    model = Pipeline([
        ('scaler', StandardScaler()),
        ('logreg', LogisticRegression(max_iter=2000))
    ])

    model.fit(X, y)
    coefs = pd.Series(model.named_steps['logreg'].coef_[0], index=service_columns)
    return coefs.sort_values(ascending=False)

# -----------------------------
# 5. Deep Dive 실행
# Customer Type → Subgroup → Regression
# -----------------------------
results = []

for ctype, cdf in groups.items():  
    for subgroup, values in sub_conditions.items():

        for val in values:

            sub_df = cdf[cdf[subgroup] == val]

            if len(sub_df) < 80:
                continue

            coefs = run_regression(sub_df, service_columns)

            if coefs is not None:
                results.append({
                    "Customer Type": ctype,
                    "Subgroup": subgroup,
                    "Value": val,
                    "Top1": f"{coefs.index[0]} ({coefs.iloc[0]:.3f})",
                    "Top2": f"{coefs.index[1]} ({coefs.iloc[1]:.3f})",
                    "Top3": f"{coefs.index[2]} ({coefs.iloc[2]:.3f})",
                })

deep_dive_df = pd.DataFrame(results)
deep_dive_df
# Out:
#    Customer Type        Subgroup            Value  \
# 0          Loyal          Gender             Male
# 1          Loyal          Gender           Female
# 2          Loyal        AgeGroup              10대
# 3          Loyal        AgeGroup              20대
# 4          Loyal        AgeGroup              60대
# 5          Loyal        AgeGroup              40대
# 6          Loyal        AgeGroup              50대
# 7          Loyal        AgeGroup              30대
# 8          Loyal        AgeGroup             70대+
# 9          Loyal           Class         Eco Plus
# 10         Loyal           Class         Business
# 11         Loyal           Class              Eco
# 12         Loyal   DistanceGroup            Short
# 13         Loyal   DistanceGroup           Medium
# 14         Loyal   DistanceGroup             Long
# 15         Loyal  Type of Travel  Personal Travel
# 16         Loyal  Type of Travel  Business travel
# 17      Disloyal          Gender             Male
# 18      Disloyal          Gender           Female
# 19      Disloyal        AgeGroup              10대
# 20      Disloyal        AgeGroup              20대
# 21      Disloyal        AgeGroup              60대
# 22      Disloyal        AgeGroup              40대
# 23      Disloyal        AgeGroup              50대
# 24      Disloyal        AgeGroup              30대
# 25      Disloyal        AgeGroup             70대+
# 26      Disloyal           Class         Eco Plus
# 27      Disloyal           Class         Business
# 28      Disloyal           Class              Eco
# 29      Disloyal   DistanceGroup            Short
# 30      Disloyal   DistanceGroup           Medium
# 31      Disloyal  Type of Travel  Personal Travel
# 32      Disloyal  Type of Travel  Business travel
#
#                              Top1                            Top2  \
# 0         Online boarding (1.438)  Inflight entertainment (0.545)
# 1   Inflight wifi service (0.777)         Online boarding (0.762)
# 2         Online boarding (2.352)          Food and drink (2.172)
# 3         Online boarding (2.228)          Food and drink (2.100)
# 4   Inflight wifi service (0.923)        Leg room service (0.851)
# 5        Leg room service (0.817)         Online boarding (0.738)
# 6        Leg room service (0.882)   Inflight wifi service (0.776)
# 7         Online boarding (1.185)  Inflight entertainment (0.688)
# 8        Leg room service (0.708)  Inflight entertainment (0.656)
# 9   Inflight wifi service (2.267)  Inflight entertainment (0.504)
# 10       Leg room service (0.634)         Checkin service (0.598)
# 11  Inflight wifi service (2.508)  Inflight entertainment (0.348)
# 12        Online boarding (1.001)   Inflight wifi service (0.914)
# 13        Online boarding (0.909)        Leg room service (0.564)
# 14        Checkin service (0.681)             Cleanliness (0.588)
# 15  Inflight wifi service (2.649)         Online boarding (0.306)
# 16        Checkin service (0.733)        On-board service (0.683)
# 17  Inflight wifi service (2.702)          Food and drink (2.049)
# 18  Inflight wifi service (2.675)          Food and drink (1.974)
# 19  Inflight wifi service (2.828)         Online boarding (1.536)
# 20         Food and drink (3.135)   Inflight wifi service (3.078)
# 21  Inflight wifi service (1.192)          Food and drink (1.036)
# 22  Inflight wifi service (2.691)          Food and drink (0.426)
# 23  Inflight wifi service (2.003)          Food and drink (0.763)
# 24  Inflight wifi service (2.429)         Online boarding (0.677)
# 25        Online boarding (1.607)             Cleanliness (1.072)
# 26  Inflight wifi service (1.329)          Food and drink (0.540)
# 27  Inflight wifi service (2.666)          Food and drink (2.206)
# 28  Inflight wifi service (2.778)          Food and drink (1.747)
# 29  Inflight wifi service (2.698)          Food and drink (2.258)
# 30  Inflight wifi service (2.933)          Food and drink (0.634)
# 31  Inflight wifi service (2.280)         Online boarding (0.773)
# 32  Inflight wifi service (2.707)          Food and drink (2.150)
#
#                                          Top3
# 0               Inflight wifi service (0.532)
# 1                    Leg room service (0.663)
# 2               Inflight wifi service (0.938)
# 3              Inflight entertainment (0.435)
# 4                     Online boarding (0.597)
# 5               Inflight wifi service (0.659)
# 6                     Online boarding (0.765)
# 7               Inflight wifi service (0.467)
# 8               Inflight wifi service (0.611)
# 9                     Online boarding (0.307)
# 10                    Online boarding (0.588)
# 11                    Online boarding (0.185)
# 12             Inflight entertainment (0.443)
# 13                   On-board service (0.554)
# 14                    Online boarding (0.571)
# 15                     Food and drink (0.033)
# 16                        Cleanliness (0.625)
# 17                    Online boarding (1.842)
# 18                    Online boarding (1.687)
# 19             Inflight entertainment (0.855)
# 20                    Online boarding (2.670)
# 21                    Online boarding (0.881)
# 22  Departure/Arrival time convenient (0.327)
# 23                    Online boarding (0.733)
# 24                     Food and drink (0.634)
# 25                   Inflight service (0.718)
# 26                    Checkin service (0.384)
# 27                    Online boarding (1.918)
# 28                    Online boarding (1.609)
# 29                    Online boarding (1.972)
# 30                    Checkin service (0.305)
# 31                       Seat comfort (0.634)
# 32                    Online boarding (1.843)
